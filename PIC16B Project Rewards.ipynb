# %% [markdown]
# Converting points into dollar equivalent rewards.

# %%
from dataclasses import dataclass
from typing import Dict, Optional

# %%
import pickle
import pandas as pd
from earn_rate_parser import parse_earn_rates

with open("cards.pkl", "rb") as f:
    cards = pickle.load(f)

# Infer missing issuers (need to work on, can't open cards.pkl directly yet)
for card in cards:
    if not hasattr(card, "issuer"):
        name_lower = card.name.lower()
        if "amex" in name_lower or "american express" in name_lower:
            card.issuer = "amex"
        elif "chase" in name_lower:
            card.issuer = "chase"
        elif "capital one" in name_lower or "venture" in name_lower or "quicksilver" in name_lower:
            card.issuer = "capital_one"
        else:
            card.issuer = "unknown"

records = []
for card in cards:
    earn_rates = parse_earn_rates(card.rewards)
    records.append({
        "name": card.name,
        "issuer": card.issuer,
        "annual_fee": card.annual_fee,
        "rewards_text": str(card.rewards),
        "earn_rates": earn_rates,
    })

df = pd.DataFrame(records)
df.head(10)
# Out:
#                                                 name   issuer  \
# 0                                     Platinum Card®  unknown
# 1                        American Express® Gold Card     amex
# 2                          Blue Cash Preferred® Card  unknown
# 3                           Blue Cash Everyday® Card  unknown
# 4         Delta SkyMiles® Gold American Express Card     amex
# 5     Delta SkyMiles® Platinum American Express Card     amex
# 6       Marriott Bonvoy Bevy® American Express® Card     amex
# 7  Marriott Bonvoy Brilliant® American Express® Card     amex
# 8                Hilton Honors American Express Card     amex
# 9       Hilton Honors American Express Surpass® Card     amex
#
#                                           annual_fee  \
# 0                                             $895¤†
# 1                                             $325¤†
# 2  $0 intro annual fee for the first year, then $...
# 3                                    No Annual Fee ¤
# 4  $0 introductory annual fee for the first year,...
# 5                                              $350¤
# 6                                              $250¤
# 7                                              $650¤
# 8                                    No Annual Fee ¤
# 9                                              $150¤
#
#                                         rewards_text  \
# 0  ['5X Membership Rewards® Points on American Ex...
# 1  ['Earn 4X Points at Restaurants Worldwide', 'E...
# 2  ['6% Cash Back at U.S. Supermarkets', '6% Cash...
# 3  ['3% Cash Back at U.S. Supermarkets', '3% Cash...
# 4  ['TakeOff 15', '$200 Delta Flight Credit', 'Ea...
# 5  ['Annual Companion Certificate', 'Get closer t...
# 6  ['6X Marriott Bonvoy® Points at Participating ...
# 7  ['6X Marriott Bonvoy Points at Participating H...
# 8  ['7X Hilton Honors Bonus Points on Hilton Purc...
# 9  ['12X Hilton Honors Bonus Points on Hilton Pur...
#
#                                           earn_rates
# 0                      {'travel': 5.0, 'other': 1.0}
# 1  {'dining': 4.0, 'groceries': 3.0, 'travel': 3....
# 2  {'groceries': 6.0, 'entertainment': 3.0, 'tran...
# 3  {'groceries': 3.0, 'entertainment': 1.0, 'othe...
# 4  {'travel': 2.0, 'dining': 2.0, 'groceries': 1....
# 5                      {'travel': 3.0, 'other': 1.0}
# 6  {'travel': 6.0, 'dining': 6.0, 'groceries': 2....
# 7       {'other': 6.0, 'travel': 6.0, 'dining': 6.0}
# 8  {'dining': 1.0, 'groceries': 1.0, 'other': 3.0...
# 9  {'dining': 1.0, 'groceries': 1.0, 'transit': 4...

# %%
# More concise dataframe
card_df = []
for card in cards:
    earn_rates = parse_earn_rates(card.rewards)
    card_df.append({
        "name": card.name,
        "rewards_text": str(card.rewards),
        "earn_rates": earn_rates,
    })

df2 = pd.DataFrame(card_df)
df2.head(20)
# Out:
#                                                  name  \
# 0                                      Platinum Card®
# 1                         American Express® Gold Card
# 2                           Blue Cash Preferred® Card
# 3                            Blue Cash Everyday® Card
# 4          Delta SkyMiles® Gold American Express Card
# 5      Delta SkyMiles® Platinum American Express Card
# 6        Marriott Bonvoy Bevy® American Express® Card
# 7   Marriott Bonvoy Brilliant® American Express® Card
# 8                 Hilton Honors American Express Card
# 9        Hilton Honors American Express Surpass® Card
# 10      Delta SkyMiles® Reserve American Express Card
# 11                       American Express Green Card®
# 12         Hilton Honors American Express Aspire Card
# 13         Delta SkyMiles® Blue American Express Card
# 14                                Platinum Mastercard
# 15                                  Venture X Rewards
# 16                                    Venture Rewards
# 17                                 VentureOne Rewards
# 18                 VentureOne Rewards for Good Credit
# 19                                Quicksilver Rewards
#
#                                          rewards_text  \
# 0   ['5X Membership Rewards® Points on American Ex...
# 1   ['Earn 4X Points at Restaurants Worldwide', 'E...
# 2   ['6% Cash Back at U.S. Supermarkets', '6% Cash...
# 3   ['3% Cash Back at U.S. Supermarkets', '3% Cash...
# 4   ['TakeOff 15', '$200 Delta Flight Credit', 'Ea...
# 5   ['Annual Companion Certificate', 'Get closer t...
# 6   ['6X Marriott Bonvoy® Points at Participating ...
# 7   ['6X Marriott Bonvoy Points at Participating H...
# 8   ['7X Hilton Honors Bonus Points on Hilton Purc...
# 9   ['12X Hilton Honors Bonus Points on Hilton Pur...
# 10  ['Delta Sky Club® Access & Delta Sky Club® One...
# 11  ['Earn 3X Points on Travel', 'Earn 3X Points o...
# 12  ['14X Hilton Honors Bonus Points on Hilton Pur...
# 13  ['Earn 2X Miles at Restaurants', 'Earn 2X Mile...
# 14        Get the credit you need with no annual fee.
# 15  Earn unlimited 10X miles on hotels and rental ...
# 16  Earn unlimited 2 miles per dollar on every pur...
# 17  Earn unlimited 1.25 miles per dollar on every ...
# 18  Earn unlimited 1.25 miles per dollar on every ...
# 19  Earn unlimited 1.5% cash back on every purchas...
#
#                                            earn_rates
# 0                       {'travel': 5.0, 'other': 1.0}
# 1   {'dining': 4.0, 'groceries': 3.0, 'travel': 3....
# 2   {'groceries': 6.0, 'entertainment': 3.0, 'tran...
# 3   {'groceries': 3.0, 'entertainment': 1.0, 'othe...
# 4   {'travel': 2.0, 'dining': 2.0, 'groceries': 1....
# 5                       {'travel': 3.0, 'other': 1.0}
# 6   {'travel': 6.0, 'dining': 6.0, 'groceries': 2....
# 7        {'other': 6.0, 'travel': 6.0, 'dining': 6.0}
# 8   {'dining': 1.0, 'groceries': 1.0, 'other': 3.0...
# 9   {'dining': 1.0, 'groceries': 1.0, 'transit': 4...
# 10                                     {'other': 1.0}
# 11  {'travel': 3.0, 'transit': 3.0, 'dining': 3.0,...
# 12       {'other': 3.0, 'travel': 3.0, 'dining': 3.0}
# 13     {'travel': 20.0, 'dining': 20.0, 'other': 1.0}
# 14                                     {'other': 1.0}
# 15                    {'other': 10.0, 'travel': 10.0}
# 16                      {'travel': 1.0, 'other': 1.0}
# 17                      {'travel': 1.0, 'other': 1.0}
# 18                      {'travel': 1.0, 'other': 1.0}
# 19                                     {'other': 1.0}

# %%
for card in cards:
    earn_rates = parse_earn_rates(card.rewards)
    print(f"{card.name}: {earn_rates}")
# Out:
# Platinum Card®: {'travel': 5.0, 'other': 1.0}
# American Express® Gold Card: {'dining': 4.0, 'groceries': 3.0, 'travel': 3.0, 'other': 1.0}
# Blue Cash Preferred® Card: {'groceries': 6.0, 'entertainment': 3.0, 'transit': 3.0, 'other': 1.0}
# Blue Cash Everyday® Card: {'groceries': 3.0, 'entertainment': 1.0, 'other': 1.0, 'transit': 1.0}
# Delta SkyMiles® Gold American Express Card: {'travel': 2.0, 'dining': 2.0, 'groceries': 1.0, 'other': 1.0}
# Delta SkyMiles® Platinum American Express Card: {'travel': 3.0, 'other': 1.0}
# Marriott Bonvoy Bevy® American Express® Card: {'travel': 6.0, 'dining': 6.0, 'groceries': 2.0, 'other': 2.0}
# Marriott Bonvoy Brilliant® American Express® Card: {'other': 6.0, 'travel': 6.0, 'dining': 6.0}
# Hilton Honors American Express Card: {'dining': 1.0, 'groceries': 1.0, 'other': 3.0, 'transit': 3.0}
# Hilton Honors American Express Surpass® Card: {'dining': 1.0, 'groceries': 1.0, 'transit': 4.0, 'other': 3.0}
# Delta SkyMiles® Reserve American Express Card: {'other': 1.0}
# American Express Green Card®: {'travel': 3.0, 'transit': 3.0, 'dining': 3.0, 'other': 1.0}
# Hilton Honors American Express Aspire Card: {'other': 3.0, 'travel': 3.0, 'dining': 3.0}
# Delta SkyMiles® Blue American Express Card: {'travel': 20.0, 'dining': 20.0, 'other': 1.0}
# Platinum Mastercard: {'other': 1.0}
# Venture X Rewards: {'other': 10.0, 'travel': 10.0}
# Venture Rewards: {'travel': 1.0, 'other': 1.0}
# VentureOne Rewards: {'travel': 1.0, 'other': 1.0}
# VentureOne Rewards for Good Credit: {'travel': 1.0, 'other': 1.0}
# Quicksilver Rewards: {'other': 1.0}
# Quicksilver Rewards for Good Credit: {'other': 1.0}
# Savor Rewards: {'entertainment': 3.0, 'other': 3.0, 'dining': 3.0}
# Savor Rewards for Good Credit: {'entertainment': 3.0, 'other': 3.0, 'dining': 3.0}
# SavorOne Rewards: {'entertainment': 3.0, 'other': 3.0, 'dining': 3.0}
# QuicksilverOne Rewards: {'other': 1.0}
# Savor Rewards for Students: {'entertainment': 3.0, 'other': 3.0, 'dining': 3.0}
# Quicksilver Rewards for Students: {'other': 1.0}
# Quicksilver Secured Rewards: {'other': 1.0}
# Platinum Secured: {'other': 1.0}
# T-Mobile Visa: {'other': 1.0}
# Kohl's Rewards Visa: {'other': 1.0}
# REI Co-op Mastercard: {'other': 5.0}
# Pottery Barn Key Rewards Visa: {'dining': 4.0, 'other': 1.0}
# Williams Sonoma Key Rewards Visa: {'dining': 4.0, 'other': 1.0}
# West Elm Key Rewards Visa: {'dining': 4.0, 'other': 1.0}
# The Key Rewards Visa: {'dining': 4.0, 'other': 1.0}
# Spark 2% Cash Plus: {'other': 1.0}
# Spark 2% Cash: {'other': 1.0}
# Spark 1.5% Cash Select: {'other': 1.0}
# Spark 1% Classic: {'other': 1.0}
# Venture X Business: {'travel': 2.0, 'other': 1.0}
# Spark 2X Miles: {'travel': 2.0, 'other': 1.0}
# Spark 1.5X Miles Select: {'travel': 5.0, 'other': 1.0}
# Cabelas CLUB Card: {'other': 1.0}
# Bass Pro Shops  CLUB Card: {'other': 1.0}
# Bass Pro Shops and Cabela's CLUB Business card: {'other': 1.0}
# BJs One Mastercard: {'transit': 1.0, 'other': 1.0}
# BJs One+ Mastercard: {'transit': 1.0, 'other': 1.0}
# The New Chase Sapphire Reserve® Credit Card: {'travel': 10.0, 'dining': 10.0, 'other': 10.0}
# Chase Sapphire Preferred® Credit Card: {'other': 2.0, 'travel': 5.0, 'dining': 3.0, 'entertainment': 3.0}
# Chase Freedom Unlimited®  Credit Card: {'dining': 3.0, 'other stores': 3.0, 'travel': 5.0, 'other': 5.0}
# Chase Freedom Flex®  Credit Card: {'transit': 5.0, 'travel': 5.0, 'dining': 3.0, 'other stores': 3.0, 'other': 1.0}
# Chase Freedom Rise® Credit Card: {'other': 1.0}
# Slate Edge®  Credit Card: {'other': 1.0}
# UnitedSM Explorer Card: {'travel': 7.0, 'other': 2.0, 'dining': 2.0}
# United QuestSM Card: {'travel': 8.0, 'other': 5.0, 'transit': 2.0, 'dining': 2.0, 'entertainment': 2.0}
# United GatewaySM Card: {'travel': 25.0, 'other': 2.0, 'transit': 2.0}
# United ClubSM Card: {'travel': 9.0, 'other': 4.0, 'transit': 2.0, 'dining': 2.0}
# Southwest Rapid Rewards® Plus Credit Card: {'travel': 25.0, 'transit': 1.0, 'other': 1.0}
# Southwest Rapid Rewards® Priority  Credit Card: {'travel': 25.0, 'transit': 1.0, 'dining': 1.0, 'other': 1.0}
# Southwest Rapid Rewards® Premier Credit Card: {'travel': 25.0, 'dining': 1.0, 'other': 1.0}
# Marriott Bonvoy Boundless® Credit Card: {'travel': 6.0, 'transit': 3.0, 'dining': 3.0, 'other': 2.0}
# Marriott Bonvoy Bountiful® Credit Card: {'travel': 6.0, 'dining': 4.0, 'other': 2.0}
# Marriott Bonvoy Bold® Credit Card: {'travel': 10.0, 'entertainment': 2.0, 'other': 1.0}
# IHG One Rewards Premier Credit Card: {'travel': 10.0, 'transit': 10.0, 'dining': 10.0, 'other': 3.0}
# IHG One Rewards Traveler Credit Card: {'travel': 1.0, 'entertainment': 10.0, 'transit': 10.0, 'dining': 10.0, 'other': 2.0}
# Disney® Premier Visa® Card: {'travel': 1.0, 'transit': 2.0, 'dining': 2.0, 'other': 1.0}
# Disney® Visa® Card: {'travel': 0.0, 'other': 1.0}
# World of Hyatt Credit Card: {'travel': 1.0, 'transit': 1.0, 'dining': 1.0, 'other': 1.0}
# Aeroplan® Card: {'dining': 3.0, 'other': 1.0, 'travel': 1.0}
# British Airways Visa Signature® Credit Card: {'travel': 50.0, 'other': 1.0}
# Aer Lingus Visa Signature® Credit Card: {'travel': 1.0, 'other': 1.0}
# Iberia Visa Signature® Credit Card: {'travel': 1.0, 'other': 1.0}
# Prime Visa: {'travel': 1.0, 'transit': 2.0, 'dining': 2.0, 'other': 1.0}
# Amazon Visa: {'travel': 1.0, 'transit': 2.0, 'dining': 2.0, 'other': 1.0}
# DoorDash Rewards Mastercard®: {'groceries': 1.0, 'dining': 1.0, 'other': 1.0}
# Instacart Mastercard®: {'entertainment': 1.0, 'transit': 1.0, 'dining': 1.0, 'other': 1.0}
# The New Sapphire Reserve for BusinessSM Credit Card: {'travel': 5.0, 'other': 1.0}
# Ink Business Unlimited® Credit Card: {'other': 1.0}
# Ink Business Preferred® Credit Card: {'other': 1.0}
# Ink Business Cash® Credit Card: {'other': 1.0}
# Ink Business Premier® Credit Card: {'other': 1.0}
# UnitedSM Business Card: {'travel': 25.0, 'other': 2.0, 'transit': 2.0, 'dining': 2.0}
# United ClubSM Business  Card: {'travel': 7.0, 'other': 5.0}
# Southwest Rapid Rewards® Performance Business Credit Card: {'travel': 25.0, 'transit': 1.0, 'dining': 1.0, 'other': 1.0}
# Southwest Rapid Rewards®  Premier Business Credit Card: {'travel': 25.0, 'transit': 1.0, 'dining': 1.0, 'other': 1.0}
# IHG One Rewards Premier Business Credit Card: {'travel': 10.0, 'transit': 10.0, 'dining': 10.0, 'other': 3.0}
# World of Hyatt Business Credit Card: {'travel': 1.0, 'other': 1.0}

# %%
# How much are those points worth in dollars

# %%
# Calculate points/miles to dollar equivalents.

@dataclass
class IssuerValuation:
    """
    Represents a valuation model for a single issuer's points/miles.
    """
    issuer: str
    dollars_per_point: Dict[str, float]

    def get_value_per_point(self, redemption_type: str = "baseline") -> float:
        """
        Returns the dollar value of 1 point for the given redemption_type.
        Default 'baseline' if redemption_type is missing.
        """
        if redemption_type in self.dollars_per_point:
            return self.dollars_per_point[redemption_type]
        return self.dollars_per_point.get("baseline", 0.0)

    def points_to_dollars(self, points: float, redemption_type: str = "baseline") -> float:
        """
        Convert a number of points to a dollar equivalent using this valuation model.
        """
        return points * self.get_value_per_point(redemption_type)

    def effective_cashback_rate(self, points_per_dollar_spent: float,
        redemption_type: str = "baseline") -> float:
        """
        Given an earn rate (points per $1 spent), return the effective cashback rate
        as a decimal fraction.
        """
        value_per_point = self.get_value_per_point(redemption_type)
        return points_per_dollar_spent * value_per_point

# %%
# Issuer valuations according to NerdWallet

ISSUER_MODELS = {
    "amex": IssuerValuation(
        issuer="amex",
        dollars_per_point={
            "cash": 0.007,
            "travel_portal": 0.010,
            "travel_transfer": 0.018,
            "baseline": 0.015,
        }
    ),
    "chase": IssuerValuation(
        issuer="chase",
        dollars_per_point={
            "cash": 0.010,
            "travel_portal": 0.013,
            "travel_transfer": 0.020,
            "baseline": 0.015,
        }
    ),
    "capital_one": IssuerValuation(
        issuer="capital_one",
        dollars_per_point={
            "cash": 0.005,
            "travel_portal": 0.010,
            "travel_transfer": 0.018,
            "baseline": 0.012,
        }
    )
}

def get_issuer_model(issuer: str) -> Optional[IssuerValuation]:
    """
    Fetch the IssuerValuation by an issuer string.

    Expected issuer strings (matches scrapers):
      - 'amex'
      - 'chase'
      - 'capital_one'
    """
    key = issuer.lower().strip()
    return ISSUER_MODELS.get(key)

def estimate_points_value(issuer: str, points: float, redemption_type: str = "baseline") -> float:
    """
    Given issuer, number of points, and redemption type,
    return an estimated dollar value.
    """
    model = get_issuer_model(issuer)
    if model is None:
        # If we don't know the issuer, assume 1¢/point as a generic fallback
        return points * 0.01
    return model.points_to_dollars(points, redemption_type)


def estimate_effective_cashback(
    issuer: str,
    points_per_dollar_spent: float,
    redemption_type: str = "baseline",
) -> float:
    """
    Given issuer, earn rate (points per $1), and redemption type,
    return effective cashback rate as a decimal.
    (Multiply by 100 to get a percentage.)
    """
    model = get_issuer_model(issuer)
    if model is None:
        # Generic fallback: 1¢/point
        return points_per_dollar_spent * 0.01
    return model.effective_cashback_rate(points_per_dollar_spent, redemption_type)

# %%
# Helper function

def category_points_to_dollars(
    issuer: str,
    category: str,
    points: float,
    earn_rates: dict,
    redemption_type: str = "baseline"
) -> float:
    """
    Convert a given number of points into dollars for a specific category.

    Parameters
    ----------
    issuer : str
        The card issuer ("amex", "chase", "capital_one").
    category : str
        The spending category chosen by the user ("dining", "entertainment", etc.)
    points : float
        Number of points the user wants to redeem.
    earn_rates : dict
        Mapping category -> points_per_dollar_spent, extracted from card rewards.
    redemption_type : str
        One of {"cash", "travel_portal", "travel_transfer", "baseline"}.

    Returns
    -------
    float
        Dollar equivalent value of the given points in that category.
    """

    issuer_model = get_issuer_model(issuer)
    if issuer_model is None:
        # Fallback: assume 1¢ per point if issuer is unknown
        return points * 0.01

    # Category affects valuation because earn rates differ
    category_rate = earn_rates.get(category, earn_rates.get("other", 1.0))

    # Convert points to dollars using issuer's valuation rules
    dollar_value = issuer_model.points_to_dollars(
        points=points,
        redemption_type=redemption_type
    )

    return dollar_value

# %%
# Example usage of helper function
"""earn_rates = {
    "dining": 4.0,
    "entertainment": 3.0,
    "other": 1.0}"""

value = category_points_to_dollars(
    issuer="amex",
    category="",
    points=4000,
    earn_rates=earn_rates,
    redemption_type="travel_transfer")

print(f"Your dollar equivalent estimate is ${value: .2f}")
# Out:
# Your dollar equivalent estimate is $ 72.00
